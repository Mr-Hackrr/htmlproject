# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Hackrr/htmlproject/blob/master/pooji_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.8 MB/s eta 0:00:00
# ...

# %%
from faker import Faker
fake = Faker()

# %%
from random import randint
import pandas as pd

fake = Faker()

def input_data(x):

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i,'id']= randint(1, 100)
        data.loc[i,'name']= fake.name()
        data.loc[i,'address']= fake.address()
        data.loc[i,'latitude']= str(fake.latitude())
        data.loc[i,'longitude']= str(fake.longitude())
    return data


input_data(10)
# Out:
#      id               name                                            address  \
# 0  59.0     Brooke Russell          27352 Howard Brooks\nStevenfurt, IA 90343
# 1  32.0     Carrie Hampton        74501 Hale Brooks\nWest Carlaland, CT 47144
# 2  90.0      Cody Richards  8264 Peterson Estate Suite 162\nJennifermouth,...
# 3  88.0  Jonathan Thompson     715 Walton Inlet Apt. 843\nPriceside, NJ 14153
# 4  14.0      Walter Snyder                   Unit 5017 Box 4759\nDPO AE 41720
# 5  77.0     Marissa Keller                   PSC 7574, Box 5884\nAPO AE 66462
# 6  46.0    Stephanie Miles  7725 Herring Turnpike Suite 582\nLewisstad, ND...
# 7  63.0     Brittany Perez    89782 Ian Parkways\nEast Kimberlyside, UT 11941
# 8  74.0        Mason Brown                   PSC 6658, Box 8909\nAPO AP 58067
# 9  20.0      Brittany Cole              02204 Joy Port\nWest Nicole, ID 88498
#
#       latitude   longitude
# 0  -10.1046625  -28.619084
# 1   -49.505976  -60.139840
# ...

# %%
from random import randint

# %%
import pandas as pd

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

def input_data(x):
    # List of product names for the cosmetics category
    product_names = ['lipstick', 'foundation', 'mirror', 'concealer', 'eyeliner', 'mascara', 'brushes', 'lipliner', 'lipgloss', 'comb', 'highlighter', 'blush']

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(product_names)
        data.loc[i, 'Price'] = round(uniform(10.0, 1000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'cosmetics'
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = fake.company()
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
    return data

# Example usage
input_data(10)
# Out:
#   product_name   Price                                        Description  \
# 0         comb  809.54                         Month image community hot.
# 1     lipgloss  970.84                    Remember suggest respond ready.
# 2     lipstick   21.65            Political report visit onto simple leg.
# 3     eyeliner   66.76                             Edge my dark marriage.
# 4     lipgloss  295.49     Public great college heart region full growth.
# 5     lipgloss  149.56  Could movie animal conference remain scientist...
# 6      brushes  579.82             Perform station not its far night eat.
# 7         comb  777.59                          Close everyone head star.
# 8       mirror  908.48            Girl teach though culture rather again.
# 9  highlighter  324.73                     Happy series hit across other.
#
#     Category  StockQuantity                          Brand  Rating  \
# 0  cosmetics           34.0       Avila, Morgan and Bailey     4.4
# ...

# %%
import pandas as pd
from random import randint, uniform, choice
from faker import Faker

fake = Faker()

def input_data(x):
    # List of product names for the cosmetics category
    product_names = ['lipstick', 'foundation', 'primer' , 'toner' , 'eyeshadow palette' , 'eyebrow palette','mirror', 'setting spray' ,'moisturizer' , 'concealer', 'eyeliner', 'mascara', 'brushes', 'lipliner', 'lipgloss', 'comb', 'highlighter', 'blush','body lotion','bronzer','eye cream','hand cream','Lip Balm', 'Lip Gloss', 'Lip Scrub','Eyebrow Powder', 'Eyebrow Gel', 'Eyebrow Pomade', 'Eyebrow Tint', 'Eyelash Curler', 'False Eyelashes', 'Eyelash Glue', 'Eyelash Primer', 'Eyelash Serum', 'Eyeshadow Primer', 'Eye Makeup Remover', 'Eye Cream', 'Eye Serum', 'Eye Mask', 'Under Eye Concealer', 'Eye Brightener', 'Eye Shadow Palette', 'Eyeliner Pencil', 'Liquid Eyeliner', 'Gel Eyeliner', 'Mascara Primer', 'Waterproof Mascara', 'Volumizing Mascara', 'Lengthening Mascara', 'Curling Mascara', 'Eyebrow Stencil', 'Eyebrow Scissors', 'Eyebrow Brush', 'Eyebrow Comb', 'Eyebrow Highlighter', 'Eyebrow Growth Serum', 'Eyelash Extensions', 'Eyelash Tint', 'Eye Drops', 'Eye Makeup Brushes', 'Eye Makeup Setting Spray','Lip Mask', 'Lip Oil', 'Lip Stain', 'Lip Liner', 'Lip Plumper', 'Lip Tint', 'Lip Butter', 'Lip Sleeping Mask', 'Lip Treatment', 'Lip Sunscreen', 'Lip Primer', 'Lip Exfoliator', 'Lip Moisturizer', 'Lip Volumizer', 'Lip Enhancer', 'Lip Color Corrector', 'Lip Repair', 'Lip Revitalizer', 'Lip Brightener', 'Lip Smoother', 'Lip Softener', 'Lip Conditioner', 'Lip Protector', 'Lip Shield', 'Lip Nourisher', 'Lip Hydrator', 'Lip Rejuvenator', 'Lip Detox', 'Lip Cleanser', 'Lip Polish', 'Lip Perfector', 'Lip Booster', 'Lip Renewal', 'Lip Revitalizing Mask', 'Lip Sleeping Balm', 'Lip Plumping Gloss', 'Lip Tinted Balm']

    # List of brands for the cosmetics category
    brands = ["L’Oréal", "Estée Lauder", "MAC Cosmetics", "Maybelline", "Clinique",
          "NARS", "Lancôme", "Revlon", "Urban Decay", "Bobbi Brown", "Chanel",
          "Dior", "Yves Saint Laurent", "Shiseido", "Benefit Cosmetics", "Too Faced",
          "Tarte", "Smashbox", "Fenty Beauty", "Huda Beauty", "Anastasia Beverly Hills",
          "Glossier", "Pat McGrath Labs", "Charlotte Tilbury", "Kiehl’s", "The Body Shop",
          "NYX Professional Makeup", "IT Cosmetics", "Hourglass", "Laura Mercier",
          "CoverGirl", "E.l.f. Cosmetics", "BareMinerals", "Morphe", "ColourPop",
          "Milani", "Burt’s Bees", "Drunk Elephant", "Origins", "Pixi Beauty"]

    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i, 'product_name'] = choice(product_names)
        data.loc[i, 'Price'] = round(uniform(100.0, 5000.0), 2)
        data.loc[i, 'Description'] = fake.sentence()
        data.loc[i, 'Category'] = 'cosmetics'
        data.loc[i, 'StockQuantity'] = randint(1, 100)
        data.loc[i, 'Brand'] = choice(brands)
        data.loc[i, 'Rating'] = round(uniform(1.0, 5.0), 1)
        data.loc[i, 'Warehouse'] = fake.city()
    return data

# Example usage
input_data(10)
# Out:
#                product_name    Price  \
# 0        Eyelash Extensions   554.78
# 1        Volumizing Mascara  2139.34
# 2               Lip Plumper   179.63
# 3                 Lip Liner  3811.69
# 4        Eyelash Extensions  2256.00
# 5           Lip Tinted Balm  4602.94
# 6               Eyebrow Gel  2852.27
# 7  Eye Makeup Setting Spray  3287.29
# 8                   mascara  3193.30
# 9           Lip Rejuvenator  1053.65
#
#                                          Description   Category  \
# 0  Toward marriage suggest church because street ...  cosmetics
# 1  Far professional nation south book among store...  cosmetics
# 2  Red individual crime college fight Republican ...  cosmetics
# 3  Building physical provide star return actually...  cosmetics
# 4          Exist find half truth full no one person.  cosmetics
# 5                      Size knowledge now hear best.  cosmetics
# 6         Front value time better skill top however.  cosmetics
# ...
