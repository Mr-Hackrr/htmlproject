# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
loans_data = pd.read_csv("loans.csv")

# %%
df = loans_data.copy()

# %%
data_frame = df
print(data_frame)
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
print(data_frame.dtypes)
# Out:
# ID                                float64
# Amount.Requested                   object
# Amount.Funded.By.Investors         object
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance           object
# Inquiries.in.the.Last.6.Months    float64
# Employment.Length                  object
# dtype: object

# %%
data_frame.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
data_frame.tail()   #print the last 5 data
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 2495       MORTGAGE         9250.00    705-709                15
# ...

# %%
data_frame.isnull() #to check the null values in dataset
# Out:
#          ID  Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  \
# 0     False             False                       False          False
# 1     False             False                       False          False
# 2     False             False                       False          False
# 3     False             False                       False          False
# 4     False             False                       False          False
# ...     ...               ...                         ...            ...
# 2495  False             False                       False          False
# 2496  False             False                       False          False
# 2497  False             False                       False          False
# 2498  False             False                       False          False
# 2499  False             False                       False          False
#
#       Loan.Length  Loan.Purpose  Debt.To.Income.Ratio  State  Home.Ownership  \
# ...

# %%
data_frame.isnull().sum()  #to find all the null values present in dataset
# Out:
# ID                                 1
# Amount.Requested                   1
# Amount.Funded.By.Investors         1
# Interest.Rate                      0
# Loan.Length                        1
# Loan.Purpose                       1
# Debt.To.Income.Ratio               1
# State                              1
# Home.Ownership                     1
# Monthly.Income                     3
# FICO.Range                         0
# Open.CREDIT.Lines                  4
# Revolving.CREDIT.Balance           3
# Inquiries.in.the.Last.6.Months     3
# Employment.Length                 78
# dtype: int64

# %%
data_frame.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
data_frame.set_index("ID")
# Out:
#         Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# ID
# 81174.0            20000                      20000         8.90%   36 months
# 99592.0            19200                      19200        12.12%   36 months
# 80059.0            35000                      35000        21.98%   60 months
# 15825.0            10000                       9975         9.99%   36 months
# 33182.0            12000                      12000        11.71%   36 months
# ...                  ...                        ...           ...         ...
# 23735.0            30000                      29950        16.77%   60 months
# 65882.0            16000                      16000        14.09%   60 months
# 55610.0            10000                      10000        13.99%   36 months
# 38576.0             6000                       6000        12.42%   36 months
# 3116.0              9000                    5242.75        13.79%   36 months
#
# ...

# %%
data_frame.reset_index(drop = True)
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
data_frame.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
new_df = data_frame.loc[list(range(10)),['ID','Amount.Requested','Interest.Rate','Monthly.Income']]

# %%
new_df.head()
# Out:
#         ID Amount.Requested Interest.Rate  Monthly.Income
# 0  81174.0            20000         8.90%         6541.67
# 1  99592.0            19200        12.12%         4583.33
# 2  80059.0            35000        21.98%        11500.00
# 3  15825.0            10000         9.99%         3833.33
# 4  33182.0            12000        11.71%         3195.00

# %%
new_df
# Out:
#         ID Amount.Requested Interest.Rate  Monthly.Income
# 1  99592.0            19200        12.12%         4583.33
# 2  80059.0            35000        21.98%        11500.00
# 3  15825.0            10000         9.99%         3833.33
# 4  33182.0            12000        11.71%         3195.00
# 5  62403.0             6000        15.31%         4891.67
# 6  48808.0            10000         7.90%         2916.67
# 7  22090.0            33500        17.14%        13863.42
# 8  76404.0            14675        14.33%         3150.00
# 9  15867.0                .         6.91%         5000.00

# %%
 new_df['ID'] = new_df['ID'].apply(lambda x:int(x))

# %%
df.iloc[:,1]
# Out:
# 0    20000
# 1    19200
# 2    35000
# 3    10000
# 4    12000
# 5     6000
# 6    10000
# 7    33500
# 8    14675
# 9        .
# Name: Amount.Requested, dtype: object

# %%
df
# Out:
#         ID Amount.Requested Interest.Rate  Monthly.Income
# 0      1.0            20000          12.3        89766.00
# 1  99592.0            19200        12.12%         4583.33
# 2  80059.0            35000        21.98%        11500.00
# 3  15825.0            10000         9.99%         3833.33
# 4  33182.0            12000        11.71%         3195.00
# 5  62403.0             6000        15.31%         4891.67
# 6  48808.0            10000         7.90%         2916.67
# 7  22090.0            33500        17.14%        13863.42
# 8  76404.0            14675        14.33%         3150.00
# 9  15867.0                .         6.91%         5000.00
